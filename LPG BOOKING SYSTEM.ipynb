# %%
from tkinter import *
from tkinter import messagebox
window = tk.Tk()
window.geometry("1000x470+0+0")

Tops = Frame(window, width = 800, height = 50, bd = 8, relief = "raise")
Tops.pack(side = TOP)


f1d = Frame(window, width = 600, height = 100, bd = 8, relief = "raise")
f1d.pack(side=LEFT)
f1 = Frame(window, width = 500, height = 50, bd = 8, relief = "raise")
f1.pack(side = TOP)
f1a = Frame(f1d, width = 400, height = 50, bd = 8, relief = "raise")
f1a.pack(anchor=W)
f1b = Frame(f1d, width = 400, height = 50, bd = 8, relief = "raise")
f1b.pack(anchor=W)
f1c = Frame(f1b, width = 400, height = 40, bd = 6, relief = "raise")
f1c.pack(anchor=W,side = LEFT)
f1e = Frame(f1, width = 400, height = 50, bd = 8, relief = "raise")
f1e.pack(anchor=W)

f1g = Frame(f1, width = 400, height = 5, bd = 8, relief = "raise")
f1g.pack(anchor=W)

label1Title = Label(Tops, text = " LPG GAS ONLINE BOOKING  ", padx = 16, pady = 16, bd = 16, fg = '#000000', font = ("arial", 36, 'bold'), bg="red",relief="raise",width=50,height=1)
label1Title.pack()


T1 = Text(f1a, height = 1, width = 65) 

# TO Create label 
l1 = Label(f1a, text = "Enter mobile number") 
l1.config(font =("Ariel", 14)) 

def Get_OTP():
    messagebox.showinfo('OTP','7173')
    
    
def verify():
    messagebox.showinfo('verification','OTP verified')    
    
b3 = Button(f1a,text='Get OTP',command=Get_OTP)


l2 = Label(f1a, text = "Enter OTP") 
l2.config(font =("Ariel", 14)) 

T2 = Text(f1a, height = 1, width = 63) 


# Create a button for the next text. 
b1 = Button(f1a, text = "SUBMIT",command=verify ) 


l1.pack() 
T1.pack()
b3.pack()
l2.pack() 
T2.pack()
b1.pack() 

def price():
    name = ent_first_name1.get('1.0', 'end')
    name1 = ent_first_name2.get('1.0', 'end')
    name2 = ent_first_name3.get('1.0', 'end')
    name3 = ent_first_name4.get('1.0', 'end')
    name4 = str(300*int(w5.get()))
    labelResult.config(text = "Name:"+ name+"id:" +name1+"Address:" +name2+"Pincode:" +name3+"total cost:"+name4 )
    


lbl_first_name1 = tk.Label(f1c, text="Customer name",font = ("arial", 8, 'bold'),)
ent_first_name1= Text(f1b, height = 1.4, width = 53) 
lbl_first_name1.pack()
ent_first_name1.pack()
lbl_first_name2 = tk.Label(f1c, text="Customer id:",font = ("arial", 8, 'bold'),)
ent_first_name2 = Text(f1b, height = 1.4, width = 53) 
lbl_first_name2.pack()
ent_first_name2.pack()
lbl_first_name3 = tk.Label(f1c, text="Address:",font = ("arial", 8, 'bold'),)
ent_first_name3 = Text(f1b, height = 1.4, width = 53) 
lbl_first_name3.pack()
ent_first_name3.pack()
lbl_first_name4 = tk.Label(f1c, text="Pincode:",font = ("arial", 8, 'bold'),)
ent_first_name4 = Text(f1b, height = 1.4, width = 53) 
lbl_first_name4.pack()
ent_first_name4.pack()
lbl_first_name5 = tk.Label(f1c, text="No of Cylinders:",font = ("arial", 8, 'bold'),)
w5 = Spinbox(f1b, from_=0, to=10)
lbl_first_name5.pack()
w5.pack(side =LEFT)
lbl_dummy = tk.Label(f1c, text="  ",font = ("arial", 8, 'bold'),) 
lbl_dummy.pack()


btn_submit = Button(master=f1b, text="SUBMIT")
btn_submit.pack(side=BOTTOM)

btn = Button(master=f1e, text="Generate bill",font = ("arial", 20, 'bold'), bg="red" ,width=25,command = price)
btn.pack()
labelResult = Label(f1g, padx = 16, pady = 16, bd = 16, fg = '#000000', font = ('arial', 10, 'bold'), bg = 'sky blue', width = 47, height = 10)
labelResult.pack()
#labelResult1 = Label(f1g, padx = 16, pady = 16, bd = 16, fg = '#000000', font = ('arial', 10, 'bold'), bg = 'sky blue', width = 23, height = 1)
#labelResult1.pack()
window.mainloop()
